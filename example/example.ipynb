# %%
using ImageContainers

# %%
# https://github.com/JuliaLang/julia-logo-graphics
c1 = storeimage("julia-logo-color.png")
# Out:
# ImageContainer{:png,Array{UInt8,1}}(UInt8[0x89, 0x50, 0x4e, 0x47, 0x0d, 0x0a, 0x1a, 0x0a, 0x00, 0x00  …  0x00, 0x00, 0x49, 0x45, 0x4e, 0x44, 0xae, 0x42, 0x60, 0x82])

# %%
# confirm `gnuplot` exists in your path
plt = read(`gnuplot -e "set terminal svg; plot sin(x)"`)
c2 = storeimage(:svg, plt)
# Out:
# ImageContainer{:svg,Array{UInt8,1}}(UInt8[0x3c, 0x3f, 0x78, 0x6d, 0x6c, 0x20, 0x76, 0x65, 0x72, 0x73  …  0x3c, 0x2f, 0x73, 0x76, 0x67, 0x3e, 0x0d, 0x0a, 0x0d, 0x0a])

# %%
using Colors
grayrands = Gray.(rand(100, 100))
c3 = storeimage(:jlc, grayrands)
# Out:
# ImageContainer{:jlc,Array{Gray{Float64},2}}(Gray{Float64}[Gray{Float64}(0.35729237508152933) Gray{Float64}(0.28261902737182387) … Gray{Float64}(0.19255664567557274) Gray{Float64}(0.9489456939151069); Gray{Float64}(0.3356383046327569) Gray{Float64}(0.9217589417476455) … Gray{Float64}(0.31111715422827) Gray{Float64}(0.2055289385507073); … ; Gray{Float64}(0.9827402980696558) Gray{Float64}(0.08979477006689751) … Gray{Float64}(0.027653343136808672) Gray{Float64}(0.21795377314490416); Gray{Float64}(0.9881008503841138) Gray{Float64}(0.28553539577788967) … Gray{Float64}(0.46021334943147796) Gray{Float64}(0.8915600750463633)])
