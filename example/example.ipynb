# %%
using ImageContainers

# %%
using Colors

# %%
c = ImageContainer{:jlc}(Gray.(rand(100, 100)))
# Out:
# ImageContainer{:jlc}(Gray{Float64}[Gray{Float64}(0.736619) Gray{Float64}(0.509152) … Gray{Float64}(0.402047) Gray{Float64}(0.46694); Gray{Float64}(0.600024) Gray{Float64}(0.484939) … Gray{Float64}(0.653904) Gray{Float64}(0.598374); … ; Gray{Float64}(0.730233) Gray{Float64}(0.977039) … Gray{Float64}(0.947908) Gray{Float64}(0.0974852); Gray{Float64}(0.156962) Gray{Float64}(0.924339) … Gray{Float64}(0.792772) Gray{Float64}(0.318722)])

# %%
c = open(`gnuplot -e "set terminal svg; plot sin(x)"`) do io
    ImageContainer{:svg}(read(io))
end
# Out:
# ImageContainer{:svg}(UInt8[0x3c, 0x3f, 0x78, 0x6d, 0x6c, 0x20, 0x76, 0x65, 0x72, 0x73  …  0x3c, 0x2f, 0x73, 0x76, 0x67, 0x3e, 0x0d, 0x0a, 0x0d, 0x0a])

# %%
c = open("example.png") do io
    ImageContainer{:png}(read(io))
end
# Out:
# ImageContainer{:png}(UInt8[0x89, 0x50, 0x4e, 0x47, 0x0d, 0x0a, 0x1a, 0x0a, 0x00, 0x00  …  0x00, 0x00, 0x49, 0x45, 0x4e, 0x44, 0xae, 0x42, 0x60, 0x82])
